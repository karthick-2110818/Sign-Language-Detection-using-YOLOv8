# %%
from ultralytics import YOLO

##Load a model
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)

# # Train the model with 2 GPUs
results = model.train(data='data.yaml', epochs=200, imgsz=640)
# Out:
# Ultralytics YOLOv8.2.21  Python-3.11.7 torch-2.3.0 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO("C:/Users/karth/Desktop/anprsys/ultralytics/runs/detect/train2/weights/best.pt")


model.predict(source="0", show=True, imgsz=320, conf=0.5)
# Out:
# 1/1: 0... Success  (inf frames of shape 640x480 at 30.00 FPS)
#
#
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 256x320 (no detections), 12.7ms
# 0: 256x320 (no detections), 12.1ms
# 0: 256x320 (no detections), 12.9ms
# 0: 256x320 (no detections), 12.0ms
# 0: 256x320 (no detections), 11.5ms
# 0: 256x320 (no detections), 12.6ms
# 0: 256x320 (no detections), 16.7ms
# 0: 256x320 (no detections), 12.1ms
# 0: 256x320 (no detections), 12.0ms
# 0: 256x320 (no detections), 23.3ms
# ...

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO(r"C:\Users\karth\Desktop\anprsys\ultralytics\runs\detect\train2\weights\best.pt")

model.predict(source="0", show=True, imgsz=320, conf=0.5, save=True)
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# Cell In[2], line 4
#       1 from ultralytics import YOLO
#       3 # Load a pretrained YOLOv8n model
# ----> 4 model = YOLO(r"C:\Users\karth\Desktop\anprsys\ultralytics\runs\detect\train2\weights\best.pt")
#       6 model.predict(source="0", show=True, imgsz=320, conf=0.5, save=True)
#
# File ~\Desktop\anprsys\ultralytics\ultralytics\models\yolo\model.py:23, in YOLO.__init__(self, model, task, verbose)
#      20     self.__dict__ = new_instance.__dict__
#      21 else:
#      22     # Continue with default YOLO initialization
# ---> 23     super().__init__(model=model, task=task, verbose=verbose)
#
# File ~\Desktop\anprsys\ultralytics\ultralytics\engine\model.py:152, in Model.__init__(self, model, task, verbose)
#     150     self._new(model, task=task, verbose=verbose)
#     151 else:
# --> 152     self._load(model, task=task)
# ...
